# %% [markdown]
# # Tutorial de Pandas API
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gabguagon/Py-datos-faltantes/blob/main/tutorial_pandas_api.ipynb)

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd

# %% [markdown]
# ## Datos de prueba

# %%
df = pd.DataFrame.from_dict(
    data = {
        "a": list("asdfasdfas"),
        "b": range(0, 10)
    }
)

df.iloc[2:5, 0] = None
df.iloc[6:7, 1] = None

df
# Out:
#       a    b
# 0     a  0.0
# 1     s  1.0
# 2  None  2.0
# 3  None  3.0
# 4  None  4.0
# 5     s  5.0
# 6     d  NaN
# 7     f  7.0
# 8     a  8.0
# 9     s  9.0

# %%
df.a.str

# %%
# df.missing

# %% [markdown]
# ## Crear una nueva clase para extender pandas

# %%
try:
    del pd.DataFrame.missing
except AttributeError:
    pass

@pd.api.extensions.register_dataframe_accessor("missing")
class DontMissMe:
    def __init__(self, pandas_obj):
        self._obj = pandas_obj

    def number_missing(self):
        return self._obj.isna().sum().sum()

    def number_complete(self):
        return self._obj.size - self._obj.missing.number_missing()

    def proportion_missing(self):
        pass

# %% [markdown]
# ## Probar uso

# %%
df = pd.DataFrame(df)

# %%
df.missing.number_missing()
# Out:
# np.int64(4)

# %%
df.missing.number_complete()
# Out:
# np.int64(16)

# %%
df.missing.proportion_missing()
